# %%
from norma import train
# Out:
# Metal device set to: Apple M1

# %%
train.training_loop()
# Out:
# Loss
# 	loss             	 (min:    0.000, max:    0.000, cur:    0.000)
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 train.training_loop()
#
# File ~/Documents/Projects/bagchal/norma/norma/train.py:160, in training_loop()
#     157 else:
#     158     draws += 1
# --> 160 model.fit(
#     161     states,
#     162     actual_rewards,
#     163     use_multiprocessing=True,
#     164     batch_size=4,
#     165     callbacks=[PlotLossesKeras()],
#     166 )
#     168 game_counter += 1
#     169 positions_counter += positions_count
#
# File ~/Library/Caches/pypoetry/virtualenvs/norma-xX0cvMXD-py3.9/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ...
